# %% [raw]
# RefereeBuffClient(buff_type=0, damage_multiplier = 0.5,robot_name="")
#
# RefereeGameStateClient(game_state,robot_name="")
#
# RefereeHitClient(which_armor,your_hp,damage=50,robot_name="")
#
# RefereePenaltyClient(penalty=0, damage = 1000,robot_name="")

# %%
import rospy
import roslib
import numpy as np
from referee_modules.referee_interface import GetInfoClient, RefereeBuffClient,RefereeGameStateClient,RefereeHitClient,RefereePenaltyClient

rospy.init_node('referee_test')

# %%
RefereePenaltyClient(robot_name="robot_0")
GetInfoClient(robot_name="robot_0")
# Out:
# {'ammo': 50,
#  'buff_left': {'nsecs': 0, 'secs': 0},
#  'buff_zone_cooltime': {'nsecs': 600000000, 'secs': 51},
#  'current_behavior_process': 2,
#  'current_behavior_style': 1,
#  'enemy_pose1': {'header': {'frame_id': '/robot_0/map',
#    'seq': 0,
#    'stamp': {'nsecs': 800000000, 'secs': 440}},
#   'pose': {'orientation': {'w': 0.970371437366606,
#     'x': 0.0,
#     'y': 0.0,
#     'z': 0.24161803232181775},
#    'position': {'x': 8.182181709909777,
#     'y': 5.050678996481334,
#     'z': -0.43903334580567255}}},
#  'enemy_pose2': {'header': {'frame_id': '',
#    'seq': 0,
#    'stamp': {'nsecs': 0, 'secs': 0}},
#   'pose': {'orientation': {'w': 0.0, 'x': 0.0, 'y': 0.0, 'z': 0.0},
#    'position': {'x': 0.0, 'y': 0.0, 'z': 0.0}}},
#  'enemy_priority': 3,
#  'game_start_time': {'nsecs': 0, 'secs': 0},
#  'game_state': 1,
#  'goal': {'etc': 0.0,
#   'header': {'frame_id': 'robot_0/map',
#    'seq': 0,
#    'stamp': {'nsecs': 200000000, 'secs': 437}},
#   'x': 1.0,
#   'xa': 0.0,
#   'y': 1.0,
#   'ya': 0.0,
#   'yaw': 3.0,
#   'yawa': 0.0},
#  'has_buff': False,
#  'how_many_enemies_detected': 0,
#  'is_enemy_1_detected': False,
#  'is_enemy_2_detected': False,
#  'is_hit': False,
#  'last_hit_time': {'nsecs': 0, 'secs': 488},
#  'locked_on_enemy': 0,
#  'my_health': -50,
#  'my_pose': {'header': {'frame_id': '/robot_0/map',
#    'seq': 0,
#    'stamp': {'nsecs': 400000000, 'secs': 728}},
#   'pose': {'orientation': {'w': 0.9697481406486647,
#     'x': 0.0,
#     'y': 0.0,
#     'z': 0.2441076477877286},
#    'position': {'x': 1.1412909561862317, 'y': 0.9919622367691903, 'z': 0.0}}},
#  'reload_zone_cooltime': {'nsecs': 0, 'secs': 0},
#  'stamp': {'nsecs': 400000000, 'secs': 728},
#  'time_passed_from_start': {'nsecs': 400000000, 'secs': 728},
#  'which_armor_hit': 1}
