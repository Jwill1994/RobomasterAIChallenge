# %%
import rospy

# %%
import roslib

# %%
import actionlib

# %%
import move_base_msgs.msg

# %%
from geometry_msgs.msg import PoseStamped, Pose, Point, Quaternion

# %%
from std_msgs.msg import Header

# %%
a = move_base_msgs.msg.MoveBaseGoal.(target_pose=())

# %%
rospy.init_node('nav_ctrl_py')
result = nav_control()
print("result: " + str(result))

# %%
def nav_control():
    action_client = actionlib.SimpleActionClient('nav_con_py',move_base_msgs.msg.MoveBaseAction)
    action_client.wait_for_server()
    
    header_ = Header
    header_.frame_id="map"
    header_.stamp=rospy.Time.now()
    
    point_ = 
    quaternion_ = 
    
    pose_ = Pose
    
    
    
    
    target_pose_ = PoseStamped
    target_pose_.header=header_

# %%
print(geometry_msgs.msg.Pose.__slots__)
print(geometry_msgs.msg.Pose._slot_types)
# Out:
# ['position', 'orientation']
# ['geometry_msgs/Point', 'geometry_msgs/Quaternion']

# %%
print(move_base_msgs.msg.MoveBaseGoal.target_pose)
# Out:
# <member 'goal' of 'MoveBaseActionGoal' objects>

# %%
  #header,pose
    header_ = std_msgs.msg.Header #stamp, frame_id
    pose = geometry_msgs.msg.Pose #position, orientation
    pose.position =
    pose.orientation =
